# %%
# !pip install pytrends
# !pip install pandas_datareader

# %%
# %matplotlib inline

# %%
import datetime as dt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from Data import Data
from matplotlib import pyplot as plt
import math
import numpy as np

# %%
model = RandomForestRegressor() # Initiate a model
# choose the time range of data:
start_date, end_date = dt.datetime.today() - dt.timedelta(days=120), dt.datetime.today()
data = Data()
# Out:
# data/finance_data.csv finance data file exists and will be loaded
# data/google_trend_data.csv : Google trend data file exist and will be loaded

# %%
# plotting each variable
data.plot_data(start_date,end_date)
# Out:
# loading additional data from  2022-01-11 00:00:00 to,  2022-01-13 18:38:49.401108
# overlap 2022-01-11T00:00:00.000000000

# %%
full_data = data.gather_data(start_date, end_date)
full_data.head()
# Out:
# loading additional data from  2022-01-11 00:00:00 to,  2022-01-13 18:38:49.401108
# overlap 2022-01-11T00:00:00.000000000
#         Date        ^GSPC       ^VIX        Volume       BTC-USD  bitcoin
# 0 2021-10-06  4363.549805  21.000000  4.903473e+10  55361.449219     67.0
# 1 2021-10-07  4399.759766  19.540001  3.680786e+10  53805.984375     62.0
# 2 2021-10-08  4391.339844  18.770000  3.480087e+10  53967.847656     52.0
# 3 2021-10-09  4391.339844  18.770000  3.249121e+10  54968.222656     47.0
# 4 2021-10-10  4391.339844  18.770000  3.952779e+10  54771.578125     48.0

# %%
full_data.tail()
# Out:
#          Date        ^GSPC   ^VIX        Volume       BTC-USD    bitcoin
# 93 2022-01-07  4677.029785  18.76  8.419661e+10  41557.902344  70.240550
# 94 2022-01-08  4677.029785  18.76  2.806636e+10  41733.941406  60.406873
# 95 2022-01-09  4677.029785  18.76  2.129438e+10  41911.601562  58.299656
# 96 2022-01-10  4670.290039  19.40  3.210423e+10  41821.261719  61.109278
# 97 2022-01-11  4713.069824  18.41  2.632765e+10  42735.855469  54.787629

# %% [markdown]
# ### Analyzing the trend of google trends vs bitcoin price

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
grouped_data = full_data.set_index("Date")
min_max_scaler = MinMaxScaler()
bitcoin_value = grouped_data["BTC-USD"]
bitcoin_value = np.array(bitcoin_value)
bitcoin_value = bitcoin_value.reshape(-1, 1)
grouped_data["BTC-USD"] = min_max_scaler.fit_transform(X = bitcoin_value)

bitcoin_value = grouped_data["bitcoin"]
bitcoin_value = np.array(bitcoin_value)
bitcoin_value = bitcoin_value.reshape(-1, 1)
grouped_data["bitcoin"] = min_max_scaler.fit_transform(X = bitcoin_value)

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(grouped_data.loc[:,"bitcoin"], marker = 'o', color='g', label="Google Trend Hits")
ax.plot(grouped_data.loc[:,"BTC-USD"], marker = 'o', color='r', label="BitCoin Price Trend")

ax.set_xlabel("Dates",size=15)
ax.set_title("Comparing the Google Trend Hits vs BitCoin Price",size=15)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.ticklabel_format(style='plain', axis='y')
ax.legend();
plt.show()

# %%
grouped_data
# Out:
#                   ^GSPC       ^VIX        Volume   BTC-USD   bitcoin
# Date
# 2021-10-06  4363.549805  21.000000  4.903473e+10  0.530723  0.409722
# 2021-10-07  4399.759766  19.540001  3.680786e+10  0.470918  0.335317
# 2021-10-08  4391.339844  18.770000  3.480087e+10  0.477142  0.186508
# 2021-10-09  4391.339844  18.770000  3.249121e+10  0.515605  0.112103
# 2021-10-10  4391.339844  18.770000  3.952779e+10  0.508044  0.126984
# ...                 ...        ...           ...       ...       ...
# 2022-01-07  4677.029785  18.760000  8.419661e+10  0.000000  0.457945
# 2022-01-08  4677.029785  18.760000  2.806636e+10  0.006768  0.311610
# 2022-01-09  4677.029785  18.760000  2.129438e+10  0.013599  0.280253
# 2022-01-10  4670.290039  19.400000  3.210423e+10  0.010126  0.322063
# 2022-01-11  4713.069824  18.410000  2.632765e+10  0.045290  0.227991
#
# [98 rows x 5 columns]

# %%
X,y = data.train_data(start_date,end_date)
model.fit(X,y)  # train the model on data
# print('finish training')
# model.save()

X_,y_ = data.test_data(start_date,end_date)
y_predicted = model.predict(X_)
print(r2_score(y_, y_predicted))
# Out:
# loading additional data from  2022-01-11 00:00:00 to,  2022-01-13 18:38:49.401108
# overlap 2022-01-11T00:00:00.000000000
# loading additional data from  2022-01-11 00:00:00 to,  2022-01-13 18:38:49.401108
# overlap 2022-01-11T00:00:00.000000000
# -14.283807480196677
